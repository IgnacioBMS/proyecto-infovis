# %%
import pandas as pd

# %%
df = pd.read_csv('database.csv')
df
# Out:
#                                        Name          Batery Acceleration  \
# 0                              Nissan Leaf          36 kWh       7.9 sec
# 1                    Porsche Taycan Turbo S        83.7 kWh      2.8 sec
# 2                    Nissan e-NV200 Evalia          36 kWh      14.0 sec
# 3          Volkswagen ID.3 Pure Performance          45 kWh      8.9 sec
# 4                                  BMW iX3           74 kWh      6.8 sec
# ..                                      ...             ...          ...
# 122                              BMW i4 M50        80.7 kWh      3.9 sec
# 123  Volvo XC40 Recharge Twin Pure Electric          75 kWh      4.9 sec
# 124          Renault Megane E-Tech Electric         60 kWh       8.0 sec
# 125        Peugeot e-Rifter Standard 50 kWh         45 kWh      11.7 sec
# 126            Peugeot e-Rifter Long 50 kWh         45 kWh      11.7 sec
#
#      TopSpeed   Range Efficiency  NumberofSeats PriceinEurope
# ...

# %%
df = df.sort_values(by='PriceinEurope')
df = df.reset_index(drop=True)
df
# Out:
#                                      Name  Battery kwh  Acceleration sec  \
# 0                   Smart EQ fortwo coupe           16                11
# 1                       Smart EQ forfour            16                12
# 2                  Smart EQ fortwo cabrio           16                11
# 3              Fiat 500e Hatchback 24 kWh           23                 9
# 4              Fiat 500e Hatchback 42 kWh           37                 9
# ..                                    ...          ...               ...
# 122                  Porsche Taycan Turbo           83                 3
# 123    Porsche Taycan Turbo Cross Turismo           83                 3
# 124                Porsche Taycan Turbo S           83                 2
# 125  Porsche Taycan Turbo S Cross Turismo           83                 2
# 126                       Tesla Roadster           200                 2
#
#      TopSpeed km/h  Range km  Efficiency Wh/km  NumberofSeats  PriceinEurope  \
# ...

# %%
df.to_csv('database.csv', index=False)
