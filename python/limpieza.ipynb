# %%
import pandas as pd

# %%
df = pd.read_csv('../datos/database.csv')
df
# Out:
#                                      Name  Battery_kWh  Acceleration_sec  \
# 0                   Smart EQ fortwo coupe         16.7              11.6
# 1                       Smart EQ forfour          16.7              12.7
# 2                  Smart EQ fortwo cabrio         16.7              11.9
# 3              Fiat 500e Hatchback 24 kWh         23.8               9.5
# 4              Fiat 500e Hatchback 42 kWh         37.3               9.0
# ..                                    ...          ...               ...
# 122                  Porsche Taycan Turbo         83.7               3.2
# 123    Porsche Taycan Turbo Cross Turismo         83.7               3.3
# 124                Porsche Taycan Turbo S         83.7               2.8
# 125  Porsche Taycan Turbo S Cross Turismo         83.7               2.9
# 126                       Tesla Roadster         200.0               2.1
#
#      TopSpeed_kmh  Range_km  Efficiency_Whkm  NumberofSeats  PriceinEurope  \
# ...

# %%
nombres_deseados = ['Smart EQ fortwo cabrio', 'Tesla Roadster ', 'Tesla Cybertruck Dual Motor', 'Mercedes EQS 450+', 'Porsche Taycan 4 Cross Turismo', 'Opel Zafira-e Life L 50 kWh']
df = df[df['Name'].isin(nombres_deseados)]

# %%
df
# Out:
#                                Name  Battery_kWh  Acceleration_sec  \
# 2            Smart EQ fortwo cabrio         16.7              11.9
# 72      Opel Zafira-e Life L 50 kWh         45.0              12.1
# 74      Tesla Cybertruck Dual Motor        120.0               5.0
# 106  Porsche Taycan 4 Cross Turismo         83.7               5.1
# 113               Mercedes EQS 450+        107.8               6.2
# 126                 Tesla Roadster         200.0               2.1
#
#      TopSpeed_kmh  Range_km  Efficiency_Whkm  NumberofSeats  PriceinEurope  \
# 2           130.0      95.0            176.0              2          21720
# 72          130.0     180.0            250.0              7          54625
# 74          190.0     460.0            261.0              7          55000
# 106         220.0     405.0            207.0              4          93635
# 113         210.0     640.0            168.0              5         106374
# ...

# %%
df.to_csv('database.csv', index=False)
